# %% [markdown]
# <a href="https://colab.research.google.com/github/Long-Bell/Prog2kakushin/blob/main/work3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 最初に実行してください

# %%
# !wget "https://drive.google.com/uc?export=download&id=1hsUauww6HMD9YMejBh72as9x9wNCWeBc" -O images.zip
# !unzip -o images.zip
# Out:
# --2024-01-23 07:33:25--  https://drive.google.com/uc?export=download&id=1hsUauww6HMD9YMejBh72as9x9wNCWeBc
# Resolving drive.google.com (drive.google.com)... 74.125.139.101, 74.125.139.100, 74.125.139.139, ...
# Connecting to drive.google.com (drive.google.com)|74.125.139.101|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1hsUauww6HMD9YMejBh72as9x9wNCWeBc&export=download [following]
# --2024-01-23 07:33:25--  https://drive.usercontent.google.com/download?id=1hsUauww6HMD9YMejBh72as9x9wNCWeBc&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 74.125.31.132, 2607:f8b0:400c:c02::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|74.125.31.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 391994 (383K) [application/octet-stream]
# Saving to: ‘images.zip’
#
# ...

# %% [markdown]
# スマホのホーム画面のような画像が作成できます.

# %%
import numpy as np
import cv2,sys
from google.colab.patches import cv2_imshow

flower = cv2.imread('flower.jpg')
if flower is None:
  sys.exit('エラー：ファイルを開けませんでした')
img = cv2.blur(flower,(7,1))
img1 = img[0:160, 0:90]
home = cv2.resize(img1, (360,640))
h = home.shape[0] #高さ
w = home.shape[1] #幅
img_gray = np.zeros((h,w,3), np.uint8)
img_gray[:,:,0:3] = [125,125,125]
cv2.rectangle(img_gray, (12,530),(348,630), color=(90,90,90), thickness=-1)
for iy in range(h):
  for ix in range(w):
    p1 = home[iy,ix]
    p2 = img_gray[iy,ix]
    p3 = 0.3*p1+(1-0.3)*p2
    home[iy,ix] = p3
cv2_imshow(home)
print('これがホーム画面の背景です')
print()

img_set = np.zeros((100,100,3), np.uint8)
img_set[:,:,0:3] = [183,179,179]
cv2.circle(img_set, center=(50,50), radius=30, color=(48,46,46), thickness=-1)
cv2.circle(img_set, center=(50,50), radius=15, color=(183,179,179), thickness=-1)
cv2.rectangle(img_set, (43,15), (57,25), (48,46,46),thickness=-1)
cv2.rectangle(img_set, (15,43), (25,57), (48,46,46),thickness=-1)
cv2.rectangle(img_set, (43,75), (57,85), (48,46,46),thickness=-1)
cv2.rectangle(img_set, (75,43), (85,57), (48,46,46),thickness=-1)
rot_rectangle1 = ((28,29), (14,10),-45)
box1 = cv2.boxPoints(rot_rectangle1)
box1 = np.int0(box1) #整数値に変換
Rectangle = cv2.drawContours(img_set,[box1],0,(48,46,46),-1)
rot_rectangle2 = ((28,71), (14,10),45)
box2 = cv2.boxPoints(rot_rectangle2)
box2 = np.int0(box2) #整数値に変換
Rectangle = cv2.drawContours(img_set,[box2],0,(48,46,46),-1)
rot_rectangle3 = ((72,29), (14,10),45)
box3 = cv2.boxPoints(rot_rectangle3)
box3 = np.int0(box3) #整数値に変換
Rectangle = cv2.drawContours(img_set,[box3],0,(48,46,46),-1)
rot_rectangle4 = ((74,72), (14,10),-45)
box4 = cv2.boxPoints(rot_rectangle4)
box4 = np.int0(box4) #整数値に変換
Rectangle = cv2.drawContours(img_set,[box4],0,(48,46,46),-1)
set = cv2.resize(img_set,(60,60))

img_insta = np.zeros((100,100,3), np.uint8)
img_insta[:,:,0:3] = [212,45,210]
cv2.rectangle(img_insta, (20,20), (80,80), (255,255,255),thickness=5)
cv2.circle(img_insta, center=(50,50), radius=15, color=(255,255,255), thickness=5)
cv2.circle(img_insta, center=(70,33), radius=4, color=(255,255,255), thickness=-1)
img_insta2 = np.zeros((100,100,3), np.uint8)
img_insta2[:,:,0:3] = [117,52,232]
insta = cv2.resize(img_insta,(60,60))

img_app = np.zeros((100,100,3), np.uint8)
img_app[:,:,0:3] = [241,166,80]
cv2.line(img_app,(57,20),(24,80), color=(255,255,255), thickness=7)
cv2.line(img_app,(43,20),(76,80), color=(255,255,255), thickness=7)
cv2.line(img_app,(20,65),(80,65), color=(255,255,255), thickness=7)
app = cv2.resize(img_app,(60,60))

img_memo = np.zeros((100,100,3), np.uint8)
img_memo[:,:,0:3] = [255,255,255]
cv2.rectangle(img_memo, (0,0), (100,25), (82,212,247),thickness=-1)
cv2.line(img_memo,(0,25),(100,25), color=(200,198,198), thickness=2)
cv2.line(img_memo,(0,50),(100,50), color=(200,198,198), thickness=2)
cv2.line(img_memo,(0,75),(100,75), color=(200,198,198), thickness=2)
memo = cv2.resize(img_memo,(60,60))

img_pic = np.zeros((100,100,3),np.uint8)
img_pic[:,:,0:3] = [255,255,255]
cv2.ellipse(img_pic, ((50,25),(30,40),0), color=(79,182,241), thickness=-1)
cv2.ellipse(img_pic, ((50,75),(30,40),0), color=(215,166,116), thickness=-1)
cv2.ellipse(img_pic, ((25,50),(40,30),0), color=(174,138,201), thickness=-1)
cv2.ellipse(img_pic, ((75,50),(40,30),0), color=(113,208,179), thickness=-1)
img_p = np.zeros((100,100,3),np.uint8)
img_p[:,:,0:3] = [255,255,255]
cv2.ellipse(img_p, ((33,33),(40,30),45), color=(100,127,227), thickness=-1)
cv2.ellipse(img_p, ((67,33),(40,30),-45), color=(88,223,231), thickness=-1)
cv2.ellipse(img_p, ((33,67),(40,30),-45), color=(191,142,156), thickness=-1)
cv2.ellipse(img_p, ((67,67),(40,30),45), color=(164,189,128), thickness=-1)
for iy in range(100):
  for ix in range(100):
    p1 = img_pic[iy,ix]
    p2 = img_p[iy,ix]
    p3 = 0.5*p1+(1-0.5)*p2
    img_pic[iy,ix] = p3
pic = cv2.resize(img_pic,(60,60))

img_file = np.zeros((100,100,3), np.uint8)
img_file[:,:,0:3] = [255,255,255]
cv2.rectangle(img_file, (12,30),(88,80),(233,125,61),thickness=-1)
cv2.rectangle(img_file, (12,23),(33,40),(233,125,61),thickness=-1)
cv2.rectangle(img_file, (12,40),(88,80),(237,135,66),thickness=-1)
cv2.line(img_file, (16,38),(84,38),color=(255,255,255),thickness=2)
file = cv2.resize(img_file,(60,60))

img_cam = np.zeros((100,100,3), np.uint8)
img_cam[:,:,0:3] = [187,183,184]
cv2.rectangle(img_cam, (12,30),(88,75),(47,45,45),thickness=-1)
cv2.rectangle(img_cam, (35,22),(65,30),(47,45,45),thickness=-1)
cv2.circle(img_cam, center=(50,52), radius=15, color=(187,183,184), thickness=2)
cv2.circle(img_cam, center=(72,40),radius=3,color=(85,204,242),thickness=-1)
cam = cv2.resize(img_cam,(60,60))

img_clock = np.zeros((100,100,3),np.uint8)
img_clock[:,:,0:3] = [32,32,32]
cv2.circle(img_clock, center=(50,50), radius=40, color=(255,255,255),thickness=-1)
cv2.circle(img_clock, center=(50,50), radius=4, color=(0,0,0), thickness=1)
cv2.putText(img_clock, '12', (44,23), cv2.FONT_HERSHEY_PLAIN, 0.6, (0,0,0))
cv2.putText(img_clock, '1', (65,27), cv2.FONT_HERSHEY_PLAIN, 0.7, (0,0,0))
cv2.putText(img_clock, '2', (75,37), cv2.FONT_HERSHEY_PLAIN, 0.7, (0,0,0))
cv2.putText(img_clock, '3', (80,53), cv2.FONT_HERSHEY_PLAIN, 0.7, (0,0,0))
cv2.putText(img_clock, '4', (77,70), cv2.FONT_HERSHEY_PLAIN, 0.7, (0,0,0))
cv2.putText(img_clock, '5', (65,80), cv2.FONT_HERSHEY_PLAIN, 0.7, (0,0,0))
cv2.putText(img_clock, '6', (47,85), cv2.FONT_HERSHEY_PLAIN, 0.7, (0,0,0))
cv2.putText(img_clock, '7', (30,82), cv2.FONT_HERSHEY_PLAIN, 0.7, (0,0,0))
cv2.putText(img_clock, '8', (17,70), cv2.FONT_HERSHEY_PLAIN, 0.7, (0,0,0))
cv2.putText(img_clock, '9', (15,53), cv2.FONT_HERSHEY_PLAIN, 0.7, (0,0,0))
cv2.putText(img_clock, '10', (17,37), cv2.FONT_HERSHEY_PLAIN, 0.6, (0,0,0))
cv2.putText(img_clock, '11', (28,25), cv2.FONT_HERSHEY_PLAIN, 0.6, (0,0,0))
cv2.line(img_clock, (22,74),(47,52),color=(38,38,38),thickness=2)
cv2.line(img_clock, (67,64),(53,52),color=(38,38,38),thickness=2)
clock = cv2.resize(img_clock,(60,60))

img_weather = np.zeros((100,100,3),np.uint8)
img_weather[:,:,0:3] = [220,145,75]
cv2.circle(img_weather,center=(66,39),radius=18,color=(104,215,242),thickness=-1)
cv2.line(img_weather, (30,60),(60,60),color=(253,248,241),thickness=30)
cv2.circle(img_weather, center=(40,50),radius=17,color=(253,248,241),thickness=-1)
weather = cv2.resize(img_weather,(60,60))

img_message = np.zeros((100,100,3),np.uint8)
img_message[:,:,0:3] = [123,235,129]
cv2.ellipse(img_message, ((50,50),(70,55),0), color=(255,255,255), thickness=-1)
pts = np.array(((30, 70), (20, 80), (40, 75)))
cv2.fillConvexPoly(img_message, pts, (255, 255, 255))
message = cv2.resize(img_message,(60,60))

img_line = np.zeros((100,100,3),np.uint8)
img_line[:,:,0:3] = [98,196,90]
cv2.ellipse(img_line, ((50,50),(70,58),0), color=(255,255,255), thickness=-1)
pts = np.array(((50, 78), (48, 90), (63, 77)))
cv2.fillConvexPoly(img_line, pts, (255, 255, 255))
cv2.putText(img_line, 'LINE', (24,58), cv2.FONT_HERSHEY_TRIPLEX, 0.7, (98,196,90))
line = cv2.resize(img_line,(60,60))

img_music = np.zeros((100,100,3),np.uint8)
img_music[:,:,0:3] = [107,93,231]
cv2.ellipse(img_music, ((30,75),(19,15),-10), color=(255,255,255), thickness=-1)
cv2.ellipse(img_music, ((63,70),(19,15),-10), color=(255,255,255), thickness=-1)
rot_rectangle = ((54,30), (37,13),-5)
box = cv2.boxPoints(rot_rectangle)
box = np.int0(box) #整数値に変換
Rectangle = cv2.drawContours(img_music,[box],0,(255,255,255),-1)
cv2.line(img_music, (37,32),(37,73),color=(255,255,255),thickness=3)
cv2.line(img_music, (70,24),(70,73),color=(255,255,255),thickness=3)
music = cv2.resize(img_music,(60,60))

img_call = np.zeros((100,100,3),np.uint8)
img_call[:,:,0:3] = [111,224,119]
cv2.ellipse(img_call, (57,45),(50,20),45,45,140,(255,255,255),thickness=10 )
rot_rectangle1 = ((29,30), (12,22),-35)
box1 = cv2.boxPoints(rot_rectangle1)
box1 = np.int0(box1) #整数値に変換
Rectangle = cv2.drawContours(img_call,[box1],0,(255,255,255),-1)
rot_rectangle2 = ((72,73), (12,22),-52)
box2 = cv2.boxPoints(rot_rectangle2)
box2 = np.int0(box2) #整数値に変換
Rectangle = cv2.drawContours(img_call,[box2],0,(255,255,255),-1)
call = cv2.resize(img_call,(60,60))

img_mail = np.zeros((100,100,3),np.uint8)
img_mail[:,:,0:3] = [242,166,80]
cv2.rectangle(img_mail, (15,25),(85,75), color=(255,255,255), thickness=-1)
cv2.line(img_mail, (15,25),(50,58),color=(242,166,80), thickness=2)
cv2.line(img_mail, (85,25),(50,58),color=(242,166,80), thickness=2)
cv2.line(img_mail, (15,75),(40,48),color=(242,166,80), thickness=2)
cv2.line(img_mail, (85,75),(60,48),color=(242,166,80), thickness=2)
mail = cv2.resize(img_mail,(60,60))

img_map = np.zeros((100,100,3),np.uint8)
img_map[:,:,0:3] = [254,254,254]
cv2.circle(img_map,center=(50,45),radius=20,color=(63,81,216),thickness=15)
pts = np.array(((50, 90), (40, 60), (60, 60)))
cv2.fillConvexPoly(img_map, pts, (63, 81, 216))
map = cv2.resize(img_map,(60,60))

img_safari = np.zeros((100,100,3),np.uint8)
img_safari[:,:,0:3] = [255,255,255]
cv2.circle(img_safari, center=(50,50),radius=40,color=(240,170,82),thickness=-1)
pts = np.array(((20,70), (45,48), (50,55)))
cv2.fillConvexPoly(img_safari, pts, (255,255,255))
pts2 = np.array(((80,30),(45,48),(50,55)))
cv2.fillConvexPoly(img_safari, pts2, (61,78,234))
safari = cv2.resize(img_safari, (60,60))

img_gmail = np.zeros((100,100,3),np.uint8)
img_gmail[:,:,0:3] = [255,255,255]
cv2.line(img_gmail, (18,33),(50,55),color=(63,81,216), thickness=15)
cv2.line(img_gmail, (82,33),(50,55),color=(63,81,216), thickness=15)
cv2.rectangle(img_gmail, (10,25),(24,80),(235,131,83),thickness=-1)
cv2.rectangle(img_gmail, (90,25),(76,80),(92,165,88),thickness=-1)
cv2.rectangle(img_gmail, (90,25),(75,48),(66,190,241),thickness=-1)
gmail = cv2.resize(img_gmail, (60,60))

img_gphoto = np.zeros((100,100,3),np.uint8)
img_gphoto[:,:,0:3] = [255,255,255]
cv2.ellipse(img_gphoto, (50,30), (20,20), 0, -90, 90, (63,81,216), thickness=-1)
cv2.ellipse(img_gphoto, (30,50), (20,20), 0, 180, 360, (66,190,241), thickness=-1)
cv2.ellipse(img_gphoto, (50,70), (20,20), 0, 90, 270, (92,165,88), thickness=-1)
cv2.ellipse(img_gphoto, (70,50), (20,20), 0, 0, 180, (235,131,83), thickness=-1)
gphoto = cv2.resize(img_gphoto, (60,60))

img_youtube = np.zeros((100,100,3),np.uint8)
img_youtube[:,:,0:3] = [255,255,255]
cv2.rectangle(img_youtube, (15,27),(85,73),(35,52,233),thickness=-1)
pts = np.array(((43,42), (43,58), (57, 50)))
cv2.fillConvexPoly(img_youtube, pts, (255,255,255))
youtube = cv2.resize(img_youtube, (60,60))

img_paypay = np.zeros((100,100,3),np.uint8)
img_paypay[:,:,0:3] = [61,51,233]
cv2.ellipse(img_paypay, (10,45),(70,25),0,-120,70,(255,255,255),thickness=8)
cv2.line(img_paypay,(40,20),(25,100),(255,255,255),thickness=5)
paypay = cv2.resize(img_paypay, (60,60))


app_name = ['設定','Instagram','AppStore','メモ','写真','ファイル','カメラ','天気','メッセージ','LINE','ミュージック','電話','メール','マップ','時計','Safari','Gmail','Googleフォト','YouTube',
            'PayPay']
app = [set, insta, app, memo, pic, file, cam, weather, message, line, music, call, mail, map, clock, safari, gmail, gphoto, youtube, paypay]
img3 = np.zeros((60,60*len(app),3), np.uint8)
for x in range(len(app)):
  img = app[x]
  img3[0:60, x*60:x*60+60] = img
  print(app_name[x],end=' , ')
cv2_imshow(img3)
print()
print('上の中からアプリを選んでください. これ以上配置したいアプリが無い場合「なし」と入力してください')

popped_item = []
under_item = []
under = 0
while under < 4:
  u = input('いちばん下に配置するアプリを選んでください(最大4個)\n')
  if u == 'なし':
    break
  elif u in app_name:
    a = app_name.index(u)
    under_item.append(app[a])
    #home[550:610, 24*(under+1)+60*(under):24*(under+1)+60*(under+1)] = app[a]
    popped_item.append(app_name[a])
    app_name.pop(a)
    app.pop(a)
    under += 1
  elif u in popped_item:
    print('そのアプリはすでに配置されています')
  else:
    print('もう一度入力してください：')

if len(under_item) == 1:
  home[550:610, 150:210] = under_item[0]
elif len(under_item) == 2:
  home[550:610, 108:168] = under_item[0]
  home[550:610, 192:252] = under_item[1]
elif len(under_item) == 3:
  home[550:610, 66:126] = under_item[0]
  home[550:610, 150:210] = under_item[1]
  home[550:610, 234:294] = under_item[2]
elif len(under_item) == 4:
  home[550:610, 24:84] = under_item[0]
  home[550:610, 108:168] = under_item[1]
  home[550:610, 192:252] = under_item[2]
  home[550:610, 276:336] = under_item[3]

print('選んだ状況↓')
cv2_imshow(home)


num = 0
while num<16:
  h = input('ホーム画面に配置するアプリを選んでください(最大16個)\n')
  if h == 'なし':
    break
  elif h in app_name:
    b = app_name.index(h)
    home[40*((num//4)+1)+60*(num//4):40*((num//4)+1)+60*(num//4)+60, 24*(num%4+1)+60*(num%4):24*(num%4+1)+60*(num%4+1)] = app[b]
    popped_item.append(app_name[b])
    app_name.pop(b)
    app.pop(b)
    num += 1
  elif h in popped_item:
    print('そのアプリはすでに配置されています')
  else:
    print('もう一度入力してください')

cv2_imshow(home)
# Out:
# <PIL.Image.Image image mode=RGB size=360x640>
# これがホーム画面の背景です
#
# 設定 , Instagram , AppStore , メモ , 写真 , ファイル , カメラ , 天気 , メッセージ , LINE , ミュージック , 電話 , メール , マップ , 時計 , Safari , Gmail , Googleフォト , YouTube , PayPay ,
# <PIL.Image.Image image mode=RGB size=1200x60>
# 上の中からアプリを選んでください. これ以上配置したいアプリが無い場合「なし」と入力してください
# いちばん下に配置するアプリを選んでください(最大4個)
# 電話
# いちばん下に配置するアプリを選んでください(最大4個)
# メッセージ
# いちばん下に配置するアプリを選んでください(最大4個)
# LINE
# いちばん下に配置するアプリを選んでください(最大4個)
# ミュージック
# 選んだ状況↓
# <PIL.Image.Image image mode=RGB size=360x640>
# ホーム画面に配置するアプリを選んでください(最大16個)
# 設定
# ホーム画面に配置するアプリを選んでください(最大16個)
# 写真
# ホーム画面に配置するアプリを選んでください(最大16個)
# カメラ
# ホーム画面に配置するアプリを選んでください(最大16個)
# 時計
# ホーム画面に配置するアプリを選んでください(最大16個)
# メモ
# ホーム画面に配置するアプリを選んでください(最大16個)
# 天気
# ホーム画面に配置するアプリを選んでください(最大16個)
# AppStore
# ホーム画面に配置するアプリを選んでください(最大16個)
# PayPay
# ホーム画面に配置するアプリを選んでください(最大16個)
# なし
# <PIL.Image.Image image mode=RGB size=360x640>
# True
